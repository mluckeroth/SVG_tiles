# %%
# %load_ext autoreload
# %autoreload 2
import tile_tools
from IPython.display import SVG
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = "source/subdivisons.svg"
tile_tools.get_svg_dimensions(file)
# Out:
# ('595.3', '841.9')

# %%
SVG(file)

# %%
crop_rect = (0, 0, 200, 200)
svg_cropped = tile_tools.crop_svg_svgpathtools(file, *crop_rect)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 crop_rect = (0, 0, 200, 200)
# ----> 2 svg_cropped = tile_tools.crop_svg_svgpathtools(file, *crop_rect)
#
# File ~\Desktop\git\SVG_tiles\tile_tools.py:60, in crop_svg_svgpathtools(svg_file, x, y, width, height)
#      58 # Iterate over all paths and crop them
#      59 for path in paths:
# ---> 60     cropped_path = path.crop(crop_rect)
#      61     if cropped_path:
#      62         cropped_paths.append(cropped_path)
#
# AttributeError: 'Path' object has no attribute 'crop'

# %%
import svgpathtools as spt
paths, attributes = spt.svg2paths(file)

cropped_paths = []
cropped_atts = []
for path in paths:
    rel = tile_tools.bounding_box_relationship(path.bbox(), crop_rect)

# %%
paths[0].bbox()
paths[0].intersect(
# Out:
# (125.6, 125.7, 158.2, 164.7)

# %%
[*crop_rect]
# Out:
# [0, 0, 200, 200]
